# %% [markdown]
# ## Simple Linear Regression

# %%
import pandas as pd
data = pd.read_csv("Salary_Data.csv").values
X = data[:, :-1]
y = data[:, -1]
# print(X)
# print(y)

# %% [markdown]
# ### Splitting data for training and testing

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size =1/3, random_state = 0)

# %% [markdown]
# ### Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train[:, :])
X_test = sc.transform(X_test[:, :])

# print(X_train)
# print(X_test)

# %% [markdown]
# ### Training and Predicting test set results

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)

y_hat_train = regressor.predict(X_train)
y_hat_test = regressor.predict(X_test)

# %% [markdown]
# ### Plotting and Visualizing training results

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.plot(X_train, y_hat_train, color='red')
ax.scatter(X_train, y_train, color='blue')

# %% [markdown]
# ### Plotting and Visualizing test results

# %%
fig, ax = plt.subplots()
ax.plot(X_test, y_hat_test, color='red')
ax.scatter(X_test, y_test, color='blue')
